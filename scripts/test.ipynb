# %%
from cogen_align.data.dataset import SpeechTextDataset
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("/data/speech/tts/intern/mqb/models/Qwen2.5-7B-Instruct")
ds = SpeechTextDataset("/data/speech/tts/intern/mqb/personal/cogen-align/data/manifests/train/train_50h.jsonl", tokenizer)
item = ds[0]
print(item["text_ids"][-3:])  # 最后几个 token
print(tokenizer.eos_token_id)  # 应该是 151645
# Out:
# tensor([ 16589,    915, 151645])
# 151645
